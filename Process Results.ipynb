# %%
keras_models = [
    "Xception",
    "VGG19",
    "ResNet50",
    "ResNet101",
    "InceptionV3",
    "InceptionResNetV2",
    "MobileNetV2",
    "DenseNet169",
    "NASNetMobile"
]

# %%
import glob
import os
import time
import stat

def get_results_for_network(network):

    results = []

    for file in glob.glob(f"{network}-512/logs/events*"):

        fileStatsObj = os.stat(file)
        modificationTime = time.ctime(fileStatsObj[stat.ST_MTIME])

        values = {}

        count = 0
        for e in tf.train.summary_iterator(file):
            # print("--------------------------")
            for v in e.summary.value:
                if v.tag in ['epoch_loss', 'epoch_acc', 'epoch_val_loss', 'epoch_val_acc']:
                    # print(v.tag, "=", v.simple_value)
                    values[v.tag] = v.simple_value
                    count = count +1

        if count > 0:
            
            print(file, "(", modificationTime, ")")
            
            # print("Rows: ", count)
            # print("Last:")
            # print(values)
            results.append(values)
            
    return results

# %%
def perc(x):
    return f"{x * 100:.2f} %"

# %%
import pandas as pd

df = []
for model in keras_models:
    result = get_results_for_network(model)
    line = list(map(lambda x: [perc(x['epoch_acc']), x['epoch_loss'], perc(x['epoch_val_acc']), x['epoch_val_loss']], result))
    row = [item for sublist in line for item in sublist]
    row = [model, *row]
    df.append(row)
    print(model, row)
# Out:
# Xception-512/logs/events.out.tfevents.1591705147.4ade82f4a99f ( Tue Jun  9 12:20:14 2020 )
# Xception-512/logs/events.out.tfevents.1591704631.4ade82f4a99f ( Tue Jun  9 12:11:25 2020 )
# Xception-512/logs/events.out.tfevents.1591704488.4ade82f4a99f ( Tue Jun  9 12:08:34 2020 )
# Xception-512/logs/events.out.tfevents.1591704787.4ade82f4a99f ( Tue Jun  9 12:13:57 2020 )
# Xception-512/logs/events.out.tfevents.1591705357.4ade82f4a99f ( Tue Jun  9 12:23:51 2020 )
# Xception-512/logs/events.out.tfevents.1591704955.4ade82f4a99f ( Tue Jun  9 12:16:57 2020 )
# Xception ['Xception', '98.27 %', 0.36118265986442566, '28.30 %', 0.8441742062568665, '100.00 %', 0.15223419666290283, '38.81 %', 0.9340002536773682, '88.94 %', 0.3727644085884094, '43.28 %', 0.9145281910896301, '100.00 %', 0.15320278704166412, '56.25 %', 0.8198680281639099, '94.35 %', 0.2945270836353302, '37.04 %', 0.8034186959266663, '84.87 %', 0.2681221067905426, '73.91 %', 0.5706772208213806]
# VGG19-512/logs/events.out.tfevents.1591706300.4ade82f4a99f ( Tue Jun  9 12:39:39 2020 )
# VGG19-512/logs/events.out.tfevents.1591706096.4ade82f4a99f ( Tue Jun  9 12:36:15 2020 )
# VGG19-512/logs/events.out.tfevents.1591705892.4ade82f4a99f ( Tue Jun  9 12:32:51 2020 )
# VGG19-512/logs/events.out.tfevents.1591706748.4ade82f4a99f ( Tue Jun  9 12:46:57 2020 )
# VGG19-512/logs/events.out.tfevents.1591706524.4ade82f4a99f ( Tue Jun  9 12:43:17 2020 )
# VGG19 ['VGG19', '52.52 %', 0.6909759044647217, '58.70 %', 0.6331446170806885, '45.91 %', 0.650693416595459, '51.56 %', 0.7254760265350342, '53.00 %', 0.6419318318367004, '47.76 %', 0.7298346161842346, '49.57 %', 0.6892408728599548, '33.33 %', 0.6852524280548096, '45.02 %', 0.6972825527191162, '52.83 %', 0.6980990767478943]
# ResNet50-512/logs/events.out.tfevents.1591709386.4ade82f4a99f ( Tue Jun  9 13:31:37 2020 )
# ResNet50-512/logs/events.out.tfevents.1591709731.4ade82f4a99f ( Tue Jun  9 13:37:34 2020 )
# ResNet50-512/logs/events.out.tfevents.1591708750.4ade82f4a99f ( Tue Jun  9 13:20:51 2020 )
# ResNet50-512/logs/events.out.tfevents.1591708467.4ade82f4a99f ( Tue Jun  9 13:15:50 2020 )
# ResNet50-512/logs/events.out.tfevents.1591709055.4ade82f4a99f ( Tue Jun  9 13:25:59 2020 )
# ResNet50 ['ResNet50', '100.00 %', 0.09239967167377472, '52.83 %', 0.7754145264625549, '98.70 %', 0.20176880061626434, '33.33 %', 2.1927013397216797, '100.00 %', 0.07328204810619354, '56.25 %', 0.6966978311538696, '100.00 %', 0.05868266895413399, '52.24 %', 0.7640872597694397, '66.81 %', 0.3940277695655823, '32.61 %', 1.0838931798934937]
# ResNet101-512/logs/events.out.tfevents.1591726466.4ade82f4a99f ( Tue Jun  9 18:18:16 2020 )
# ResNet101-512/logs/events.out.tfevents.1591728905.4ade82f4a99f ( Tue Jun  9 19:00:15 2020 )
# ResNet101-512/logs/events.out.tfevents.1591727212.4ade82f4a99f ( Tue Jun  9 18:31:03 2020 )
# ResNet101-512/logs/events.out.tfevents.1591716749.4ade82f4a99f ( Tue Jun  9 15:35:37 2020 )
# ResNet101-512/logs/events.out.tfevents.1591718030.4ade82f4a99f ( Tue Jun  9 15:57:35 2020 )
# ResNet101-512/logs/events.out.tfevents.1591728002.4ade82f4a99f ( Tue Jun  9 18:44:21 2020 )
# ResNet101-512/logs/events.out.tfevents.1591715689.4ade82f4a99f ( Tue Jun  9 15:17:27 2020 )
# ResNet101-512/logs/events.out.tfevents.1591716207.4ade82f4a99f ( Tue Jun  9 15:26:10 2020 )
# ResNet101-512/logs/events.out.tfevents.1591717353.4ade82f4a99f ( Tue Jun  9 15:45:17 2020 )
# ResNet101-512/logs/events.out.tfevents.1591729848.4ade82f4a99f ( Tue Jun  9 19:15:48 2020 )
# ResNet101 ['ResNet101', '100.00 %', 0.054196055978536606, '52.24 %', 0.8610167503356934, '92.21 %', 0.2717498540878296, '52.83 %', 0.9685103297233582, '100.00 %', 0.05923057347536087, '56.25 %', 0.7090829610824585, '99.58 %', 0.05715618655085564, '32.61 %', 0.8650269508361816, '99.57 %', 0.1213739886879921, '33.33 %', 0.9224435091018677, '90.76 %', 0.1788778007030487, '32.61 %', 0.9108148813247681, '100.00 %', 0.041476551443338394, '52.24 %', 0.6980787515640259, '100.00 %', 0.06467892974615097, '56.25 %', 0.7296761274337769, '62.77 %', 0.45058202743530273, '47.17 %', 1.0094422101974487, '100.00 %', 0.18520332872867584, '33.33 %', 0.9889940619468689]
# InceptionV3-512/logs/events.out.tfevents.1591730916.4ade82f4a99f ( Tue Jun  9 19:33:54 2020 )
# InceptionV3-512/logs/events.out.tfevents.1591733936.4ade82f4a99f ( Tue Jun  9 20:24:53 2020 )
# InceptionV3-512/logs/events.out.tfevents.1591731875.4ade82f4a99f ( Tue Jun  9 19:50:06 2020 )
# InceptionV3-512/logs/events.out.tfevents.1591732878.4ade82f4a99f ( Tue Jun  9 20:06:52 2020 )
# InceptionV3-512/logs/events.out.tfevents.1591735034.4ade82f4a99f ( Tue Jun  9 20:43:34 2020 )
# InceptionV3 ['InceptionV3', '100.00 %', 0.16051089763641357, '44.78 %', 1.3327335119247437, '90.91 %', 0.40261462330818176, '75.47 %', 0.6182562708854675, '100.00 %', 0.16466160118579865, '42.19 %', 1.047698974609375, '94.96 %', 0.3744153082370758, '56.52 %', 0.6406169533729553, '97.39 %', 0.36237889528274536, '33.33 %', 1.396113634109497]
# InceptionResNetV2-512/logs/events.out.tfevents.1591740909.4ade82f4a99f ( Tue Jun  9 22:24:26 2020 )
# InceptionResNetV2-512/logs/events.out.tfevents.1591736251.4ade82f4a99f ( Tue Jun  9 21:05:11 2020 )
# InceptionResNetV2-512/logs/events.out.tfevents.1591739267.4ade82f4a99f ( Tue Jun  9 21:56:26 2020 )
# InceptionResNetV2-512/logs/events.out.tfevents.1591737735.4ade82f4a99f ( Tue Jun  9 21:30:21 2020 )
# InceptionResNetV2-512/logs/events.out.tfevents.1591742708.4ade82f4a99f ( Tue Jun  9 22:55:17 2020 )
# InceptionResNetV2 ['InceptionResNetV2', '71.86 %', 0.4099717140197754, '47.17 %', 1.0793853998184204, '100.00 %', 0.24510475993156433, '38.81 %', 1.271721363067627, '96.64 %', 0.31273508071899414, '32.61 %', 1.103622317314148, '95.45 %', 0.25773298740386963, '64.06 %', 0.7597271203994751, '83.04 %', 0.439226359128952, '44.44 %', 0.853215754032135]
# MobileNetV2-512/logs/events.out.tfevents.1591747898.4ade82f4a99f ( Wed Jun 10 00:22:20 2020 )
# MobileNetV2-512/logs/events.out.tfevents.1591744536.4ade82f4a99f ( Tue Jun  9 23:25:11 2020 )
# MobileNetV2-512/logs/events.out.tfevents.1591751547.4ade82f4a99f ( Wed Jun 10 01:23:12 2020 )
# MobileNetV2-512/logs/events.out.tfevents.1591746191.4ade82f4a99f ( Tue Jun  9 23:53:04 2020 )
# MobileNetV2-512/logs/events.out.tfevents.1591749724.4ade82f4a99f ( Wed Jun 10 00:52:35 2020 )
# MobileNetV2 ['MobileNetV2', '100.00 %', 0.09151140600442886, '39.13 %', 1.3881114721298218, '100.00 %', 0.057247672230005264, '61.19 %', 0.6966062784194946, '94.35 %', 0.1708483099937439, '42.59 %', 0.7795135974884033, '100.00 %', 0.07869817316532135, '54.69 %', 0.6540173292160034, '99.57 %', 0.1780509203672409, '52.83 %', 0.808636486530304]
# DenseNet169-512/logs/events.out.tfevents.1591763007.4ade82f4a99f ( Wed Jun 10 04:37:59 2020 )
# DenseNet169-512/logs/events.out.tfevents.1591753511.4ade82f4a99f ( Wed Jun 10 01:57:02 2020 )
# DenseNet169-512/logs/events.out.tfevents.1591757947.4ade82f4a99f ( Wed Jun 10 03:12:02 2020 )
# DenseNet169-512/logs/events.out.tfevents.1591755638.4ade82f4a99f ( Wed Jun 10 02:33:44 2020 )
# DenseNet169-512/logs/events.out.tfevents.1591760398.4ade82f4a99f ( Wed Jun 10 03:54:23 2020 )
# DenseNet169 ['DenseNet169', '76.52 %', 0.36122190952301025, '31.48 %', 0.728062093257904, '100.00 %', 0.1553419977426529, '55.22 %', 0.6463730335235596, '98.74 %', 0.33914995193481445, '32.61 %', 1.1220344305038452, '99.09 %', 0.1649313122034073, '56.25 %', 0.7243621349334717, '90.04 %', 0.2713494598865509, '52.83 %', 0.763185977935791]
# NASNetMobile-512/logs/events.out.tfevents.1591768639.4ade82f4a99f ( Wed Jun 10 06:14:37 2020 )
# NASNetMobile-512/logs/events.out.tfevents.1591765730.4ade82f4a99f ( Wed Jun 10 05:24:39 2020 )
# NASNetMobile-512/logs/events.out.tfevents.1591775128.4ade82f4a99f ( Wed Jun 10 08:04:56 2020 )
# NASNetMobile-512/logs/events.out.tfevents.1591771789.4ade82f4a99f ( Wed Jun 10 07:07:55 2020 )
# NASNetMobile ['NASNetMobile', '100.00 %', 0.18255484104156494, '42.19 %', 0.8579418659210205, '96.31 %', 0.20394058525562286, '56.72 %', 0.8720000982284546, '84.85 %', 0.36138999462127686, '49.06 %', 0.9266637563705444, '71.85 %', 0.33488690853118896, '45.65 %', 0.7962505221366882]

# %%
result_df = pd.DataFrame(df)

# %%
result_df.columns = ["Model", 
                     "fold1 accuracy", "fold1 loss", "fold1 val accuracy", "fold1 val loss",
                     "fold1 accuracy", "fold1 loss", "fold1 val accuracy", "fold1 val loss",
                     "fold2 accuracy", "fold2 loss", "fold2 val accuracy", "fold2 val loss",
                     "fold2 accuracy", "fold2 loss", "fold2 val accuracy", "fold2 val loss",
                     "fold3 accuracy", "fold3 loss", "fold3 val accuracy", "fold3 val loss",
                     "fold3 accuracy", "fold3 loss", "fold3 val accuracy", "fold3 val loss",
                     "fold4 accuracy", "fold4 loss", "fold4 val accuracy", "fold4 val loss",
                     "fold4 accuracy", "fold4 loss", "fold4 val accuracy", "fold4 val loss",
                     "fold5 accuracy", "fold5 loss", "fold5 val accuracy", "fold5 val loss",
                     "fold5 accuracy", "fold5 loss", "fold5 val accuracy", "fold5 val loss",
                    ]

# %%
result_df
# Out:
#                Model fold1 accuracy  fold1 loss fold1 val accuracy  \
# 0           Xception        98.27 %    0.361183            28.30 %
# 1              VGG19        52.52 %    0.690976            58.70 %
# 2           ResNet50       100.00 %    0.092400            52.83 %
# 3          ResNet101       100.00 %    0.054196            52.24 %
# 4        InceptionV3       100.00 %    0.160511            44.78 %
# 5  InceptionResNetV2        71.86 %    0.409972            47.17 %
# 6        MobileNetV2       100.00 %    0.091511            39.13 %
# 7        DenseNet169        76.52 %    0.361222            31.48 %
# 8       NASNetMobile       100.00 %    0.182555            42.19 %
#
#    fold1 val loss fold1 accuracy  fold1 loss fold1 val accuracy  \
# 0        0.844174       100.00 %    0.152234            38.81 %
# 1        0.633145        45.91 %    0.650693            51.56 %
# 2        0.775415        98.70 %    0.201769            33.33 %
# 3        0.861017        92.21 %    0.271750            52.83 %
# 4        1.332734        90.91 %    0.402615            75.47 %
# 5        1.079385       100.00 %    0.245105            38.81 %
# 6        1.388111       100.00 %    0.057248            61.19 %
# 7        0.728062       100.00 %    0.155342            55.22 %
# 8        0.857942        96.31 %    0.203941            56.72 %
#
#    fold1 val loss fold2 accuracy  ...  fold4 val accuracy fold4 val loss  \
# 0        0.934000        88.94 %  ...                None            NaN
# 1        0.725476        53.00 %  ...                None            NaN
# 2        2.192701       100.00 %  ...                None            NaN
# 3        0.968510       100.00 %  ...             56.25 %       0.729676
# 4        0.618256       100.00 %  ...                None            NaN
# 5        1.271721        96.64 %  ...                None            NaN
# 6        0.696606        94.35 %  ...                None            NaN
# 7        0.646373        98.74 %  ...                None            NaN
# 8        0.872000        84.85 %  ...                None            NaN
#
#    fold5 accuracy fold5 loss  fold5 val accuracy fold5 val loss  \
# 0            None        NaN                None            NaN
# 1            None        NaN                None            NaN
# 2            None        NaN                None            NaN
# 3         62.77 %   0.450582             47.17 %       1.009442
# 4            None        NaN                None            NaN
# 5            None        NaN                None            NaN
# 6            None        NaN                None            NaN
# 7            None        NaN                None            NaN
# 8            None        NaN                None            NaN
#
#    fold5 accuracy fold5 loss  fold5 val accuracy fold5 val loss
# 0            None        NaN                None            NaN
# 1            None        NaN                None            NaN
# 2            None        NaN                None            NaN
# 3        100.00 %   0.185203             33.33 %       0.988994
# 4            None        NaN                None            NaN
# 5            None        NaN                None            NaN
# 6            None        NaN                None            NaN
# 7            None        NaN                None            NaN
# 8            None        NaN                None            NaN
#
# [9 rows x 41 columns]

# %%
a = 0.36118265986442566
print(f"{a * 100:.2f}%")
# Out:
# 36.12%

# %%
list(map(lambda x: (x['epoch_val_acc'], x['epoch_val_loss']), results))
# Out:
# [(0.5223880410194397, 0.6980787515640259), (0.5625, 0.7296761274337769)]
