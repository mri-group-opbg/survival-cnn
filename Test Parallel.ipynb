# %%
import tensorflow as tf

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import Input, Conv2D, Dense, concatenate
from keras.models import Model

# %%
x = Input(shape=(32,))
y = Dense(16, activation='softmax')(x)
model = Model(x, y)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import gliomi

# %%
gen = gliomi.DatasourceGenerator(
    "/data/RMN/LUCA_PASQUINI/DATI_SEGMENTATI_SCALATI_media", 
    "ALESSANDRINI_GLAUCO", 
    ["ANGELONI_GIUSEPPINA", "GATTAMORTA_NATALINA", "IONTA_LUCIANA"])

# %%
gen.masked_by_percentile("test-dataset", "T1")
# Out:
# Generating dataset for T1 with percentile 70.
# We are using ALESSANDRINI_GLAUCO as template.
# We are skipping ['ANGELONI_GIUSEPPINA', 'GATTAMORTA_NATALINA', 'IONTA_LUCIANA']
# Try fetch slices for /data/RMN/LUCA_PASQUINI/DATI_SEGMENTATI_SCALATI_media
# Unexpected error: <class 'NameError'>
# Skipping subject /data/RMN/LUCA_PASQUINI/DATI_SEGMENTATI_SCALATI_media: missing sequence T1
# Try fetch slices for /data/RMN/LUCA_PASQUINI/DATI_SEGMENTATI_SCALATI_media/ALESSANDRINI_GLAUCO
# Unexpected error: <class 'NameError'>
# Skipping subject /data/RMN/LUCA_PASQUINI/DATI_SEGMENTATI_SCALATI_media/ALESSANDRINI_GLAUCO: missing sequence T1
# Try fetch slices for /data/RMN/LUCA_PASQUINI/DATI_SEGMENTATI_SCALATI_media/ALESSANDRINI_GLAUCO/ROI
# Unexpected error: <class 'NameError'>
# Skipping subject /data/RMN/LUCA_PASQUINI/DATI_SEGMENTATI_SCALATI_media/ALESSANDRINI_GLAUCO/ROI: missing sequence T1
# ...

# %%
ls /data/RMN/LUCA_PASQUINI/DATI_SEGMENTATI_SCALATI_media/ANGELONI_GIUSEPPINA
# Out:
# ADC_registered.nii*       FLAIRscalatamedia.nii*      T1_registered.nii*
# ADC_registered.nii.gz*    MPRAGEMDC_registered.nii*   T1_registered.nii.gz*
# ADCscalatamedia.nii*      MPRAGEMDCscalatamedia.nii*  T1scalatamedia.nii*
# FLAIR_registered.nii*     ROI/                        file-list.txt*
# FLAIR_registered.nii.gz*  T1MDC_registered.nii*
# FLAIR_registered_.nii*    T1MDC_registered.nii.gz*

# %%
model = keras.applications.resnet.ResNet50(include_top=True, weights='imagenet', input_tensor=None, input_shape=(224, 224, 3), pooling=None, classes=1000)

# %%
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %%
model.input
# Out:
# <tf.Tensor 'input_3:0' shape=(?, 224, 224, 3) dtype=float32>

# %%
import numpy as np

model.fit(np.array([1, 2, 3]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-6527b3eab687> in <module>
#       1 import numpy as np
#       2
# ----> 3 model.fit(np.array([1, 2, 3]))
#
# ~.local/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1152             sample_weight=sample_weight,
#    1153             class_weight=class_weight,
# -> 1154             batch_size=batch_size)
#    1155
#    1156         # Prepare validation data.
#
# ~.local/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
# ...

# %%
in1 = Input(...)  # input of the first model
 x = Conv2D(...)(in1)
 # rest of the model
 out1 = Dense(...)(x)  # output for the first model
# Out:
#   File "<ipython-input-4-23a0420b710b>", line 2
#     x = Conv2D(...)(in1)
#     ^
# IndentationError: unexpected indent

# %%
x = concatenate([out1, out2])  # merge the outputs of the two models
out = Dense(...)(x)  # final layer of the network

# %%
x = Input(shape=(32,))
y = Dense(16, activation='softmax')(x)
model = Model(x, y)

# %%
from keras import regularizers

"""
Return CNN
"""
def get_model(data_shape):

    # Specify shape of convolution kernel
    kernel_size = (3, 3)
    n_classes = 2

    K.clear_session()

    model = Sequential()

    model.add(Conv2D(32, kernel_size, activation='relu', input_shape=data_shape))
    model.add(Conv2D(32, kernel_size, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, kernel_size, activation='relu'))
    model.add(Conv2D(64, kernel_size, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, kernel_size, activation='relu'))
    model.add(Conv2D(128, kernel_size, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())

    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(n_classes, activation='softmax'))

    # optimizer
    # learning_rate = 1e-5
    # adam = Adam(lr=learning_rate)
    sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

    model.compile(loss='binary_crossentropy',
                  optimizer=sgd,
                  metrics=['accuracy','binary_crossentropy'])

    return model

# %%
print(keras.__version__)
# Out:
# 2.2.4-tf

# %%
import tensorflow

tensorflow.__version__
# Out:
# '1.15.2'

# %%
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Concatenate
# from keras.layers import Conv2D, MaxPooling2D, BatchNormalization

# %%
cnn = Sequential()
cnn.add(Dense(16, activation='softmax', input_shape=(4, 4,)))
cnn.add(Flatten())

# %%
anagraph = Sequential()
anagraph.add(Flatten(input_shape=(16, 1, )))

# %%
outputs = concatenate([cnn.outputs[0], anagraph.outputs[0]])

# %%
final = Dense(2, activation='softmax')(outputs)

# %%
model = Model([cnn.input, anagraph.input], final)

# %%
model.summary()
# Out:
# Model: "model_37"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# dense_153_input (InputLayer)    (None, 4, 4)         0
# __________________________________________________________________________________________________
# dense_153 (Dense)               (None, 4, 16)        80          dense_153_input[0][0]
# __________________________________________________________________________________________________
# flatten_32_input (InputLayer)   (None, 16, 1)        0
# __________________________________________________________________________________________________
# flatten_31 (Flatten)            (None, 64)           0           dense_153[0][0]
# __________________________________________________________________________________________________
# flatten_32 (Flatten)            (None, 16)           0           flatten_32_input[0][0]
# ...

# %%
opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(loss='binary_crossentropy', optimizer="adam")

# %%
model.fit([[np.random.rand(4, 4)], [np.random.rand(16, 1)]], [[np.random.rand(2)]])
# Out:
# Epoch 1/1
# 1/1 [==============================] - 0s 458ms/step - loss: 0.6902

# %%
model.predict([[np.random.rand(4, 4)], [np.random.rand(16, 1)]])
# Out:
# array([[0.58654284, 0.41345719]], dtype=float32)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-f729f71241b3> in <module>
# ----> 1 model.evaluate([np.random.rand(4, 4)], [np.random.rand(16)])
#
# ~usr/local/lib/python3.6/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1347             x, y,
#    1348             sample_weight=sample_weight,
# -> 1349             batch_size=batch_size)
#    1350         # Prepare inputs, delegate logic to `test_loop`.
#    1351         if self._uses_dynamic_learning_phase():
#
# ~usr/local/lib/python3.6/dist-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     577             feed_input_shapes,
# ...

# %%
import numpy as np
np.random.rand(12, 2)
# Out:
# array([[0.66412645, 0.36679187],
#        [0.0238667 , 0.799298  ],
#        [0.22723892, 0.09006159],
#        [0.05167783, 0.0457986 ],
#        [0.16942264, 0.60161968],
#        [0.53793875, 0.87863505],
#        [0.95614481, 0.72378218],
#        [0.67516262, 0.29512247],
#        [0.44137949, 0.21546206],
#        [0.86766142, 0.03539361],
#        [0.21610816, 0.12858101],
#        [0.85633388, 0.1049857 ]])
