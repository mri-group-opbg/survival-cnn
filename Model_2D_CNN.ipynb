# %% [markdown]
# # TRAINING

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
import tensorflow.keras

# %%
'''Modules needed'''

import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization

# from keras import regularizers

from keras.optimizers import Adam, SGD

from keras import backend as K

# %% [markdown]
# # Datasource

# %%
ls datasets
# Out:
# dataset-egfr.csv  dataset-ki67.csv  dataset-survivor.csv
# dataset-idh.csv   dataset-mgmt.csv

# %%
test_size = 0.2
seed = 42
sequence = "FLAIR"
dataset_path_1 = f"datasets/dataset-dataset-{sequence}-70"
dataset_path_2 = f"dataset-FLAIR-not-tumor/"
df = pd.read_csv("datasets/dataset-survivor.csv")

(train_subject, test_subject, train_label, test_label) = train_test_split(df.iloc[:,1], df.iloc[:,2], test_size=test_size, stratify=df.iloc[:,2], random_state=seed)

print("train_subject, train_label, test_subject, test_label")
print(train_subject.shape, train_label.shape, test_subject.shape, test_label.shape)

def get_label(label):
    if label == 1.0:
        return [0, 1]
    elif label == 0.0:
        return [1, 0]
    else:
        raise Exception(f"Cannot establish what label is {label}")

train_X = []
test_X = []
train_Y = []
test_Y = []

for subject, label in zip(train_subject, train_label):
    
    for image_path in glob.glob(f'{dataset_path_1}/*/{subject}/*.png'):
        im = imageio.imread(image_path)
        im = np.expand_dims(im, axis=2)
        train_X.append(im)
        train_Y.append(get_label(label))

    for image_path in glob.glob(f'{dataset_path_2}/*/{subject}/*.png'):
        im = imageio.imread(image_path)
        im = np.expand_dims(im, axis=2)
        train_X.append(im)
        train_Y.append(get_label(label))

for subject, label in zip(test_subject, test_label):
    
    for image_path in glob.glob(f'{dataset_path_1}/*/{subject}/*.png'):
        im = imageio.imread(image_path)
        im = np.expand_dims(im, axis=2)
        test_X.append(im)
        test_Y.append(get_label(label))

    for image_path in glob.glob(f'{dataset_path_2}/*/{subject}/*.png'):
        im = imageio.imread(image_path)
        im = np.expand_dims(im, axis=2)
        test_X.append(im)
        test_Y.append(get_label(label))

train_X = np.asarray(train_X) / 255.0
test_X = np.asarray(test_X) / 255.0
train_Y = np.asarray(train_Y)
test_Y = np.asarray(test_Y)

print("trainX, trainY, testX, testY")
print(train_X.shape, train_Y.shape, test_X.shape, test_Y.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-734ef97862d6> in <module>
#       4 dataset_path_1 = f"datasets/dataset-dataset-{sequence}-70"
#       5 dataset_path_2 = f"dataset-FLAIR-not-tumor/"
# ----> 6 df = pd.read_csv("datasets/dataset-survivor.csv")
#       7
#       8 (train_subject, test_subject, train_label, test_label) = train_test_split(df.iloc[:,1], df.iloc[:,2], test_size=test_size, stratify=df.iloc[:,2], random_state=seed)
#
# NameError: name 'pd' is not defined

# %%
def save_results(model_name, model, test_x, test_y):
    # evaluate the model
    scores = model.evaluate(test_x, test_y, verbose=0)
    print("-------------------------")
    print("[", model_name, "]")
    for i in range(len(model.metrics_names)):
        print("%s: %.2f%%" % (model.metrics_names[i], scores[i]*100))
    print("-------------------------")

def save_plot(fit):

    fig = plt.figure(figsize=(40, 25))
    epoch = fit.epoch
    fontsize = 16

    plt.plot(fit.epoch, fit.history['accuracy'], marker="o", linewidth=2,
             color="steelblue", label="accuracy")

    plt.plot(epoch, fit.history['loss'], marker="o", linewidth=2,
             color="orange", label="loss")
    plt.plot(epoch, fit.history['val_accuracy'], marker="o", linewidth=2,
         color="red", label="test")
    plt.plot(epoch, fit.history['val_binary_crossentropy'], marker="o", linewidth=2,
         color="green", label="binary_crossentropy")
    plt.xlabel('epoch', fontsize=fontsize)
    plt.ylabel('% Accuracy', fontsize=fontsize)

    plt.xticks(fontsize=fontsize)
    plt.yticks(fontsize=fontsize)
    plt.legend(frameon=False, fontsize=30);

# %%
Conv2D()

# %%
from keras import regularizers

"""
Return CNN
"""
def get_model(data_shape):

    # Specify shape of convolution kernel
    kernel_size = (3, 3)
    n_classes = 2

    K.clear_session()

    model = Sequential()

    model.add(Conv2D(32, kernel_size, activation='relu', input_shape=data_shape))
    model.add(Conv2D(32, kernel_size, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, kernel_size, activation='relu'))
    model.add(Conv2D(64, kernel_size, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, kernel_size, activation='relu'))
    model.add(Conv2D(128, kernel_size, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())

    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(n_classes, activation='softmax'))

    # optimizer
    # learning_rate = 1e-5
    # adam = Adam(lr=learning_rate)
    sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

    model.compile(loss='binary_crossentropy',
                  optimizer=sgd,
                  metrics=['accuracy','binary_crossentropy'])

    return model

# %%
epochs = 40
batch_size = 16

# Early stopping
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='accuracy', mode="max", patience=5)
tensorboard_callback = keras.callbacks.TensorBoard(log_dir="logs/scalars/")

data_shape = tuple(train_X.shape[1:])
print("Data shape:", data_shape)

# Get fresh model
model = get_model(data_shape)
    
# Fit
fit = model.fit(
        train_X, train_Y, 
        epochs=epochs,
        callbacks=[tensorboard_callback, early_stopping_callback],
        validation_data=(test_X, test_Y), 
        shuffle=True,
        batch_size=batch_size)

# Save trained model
# model.save(f"{self.model_name}.h5")

# Evaluate and print (test)
save_results("example-model", model, test_X, test_Y)

# Save plot
save_plot(fit)
# Out:
# Data shape: (192, 256, 1)
# Train on 8156 samples, validate on 2295 samples
# Epoch 1/40
# 8156/8156 [==============================] - 27s 3ms/step - loss: 6.5861 - accuracy: 0.5698 - binary_crossentropy: 6.5681 - val_loss: 6.9969 - val_accuracy: 0.5438 - val_binary_crossentropy: 6.9969
# Epoch 2/40
# 8156/8156 [==============================] - 26s 3ms/step - loss: 6.5959 - accuracy: 0.5711 - binary_crossentropy: 6.5779 - val_loss: 6.9969 - val_accuracy: 0.5438 - val_binary_crossentropy: 6.9969
# Epoch 3/40
# 8156/8156 [==============================] - 25s 3ms/step - loss: 6.5959 - accuracy: 0.5711 - binary_crossentropy: 6.5779 - val_loss: 6.9969 - val_accuracy: 0.5438 - val_binary_crossentropy: 6.9969
# Epoch 4/40
# 8156/8156 [==============================] - 25s 3ms/step - loss: 6.5962 - accuracy: 0.5710 - binary_crossentropy: 6.5782 - val_loss: 6.9969 - val_accuracy: 0.5438 - val_binary_crossentropy: 6.9969
# Epoch 5/40
# 3248/8156 [==========>...................] - ETA: 13s - loss: 6.4253 - accuracy: 0.5822 - binary_crossentropy: 6.4078

# %%
import glob
import imageio
import glob
import numpy as np

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import pandas as pd

class Datasource():
    
    def __init__(self, dataset_path, subjects_path):

        zeros = len(glob.glob(f"{dataset_path}/0.0/*/*.png"))
        ones = len(glob.glob(f"{dataset_path}/1.0/*/*.png"))
        images = zeros + ones
        print(f"Loading {images} images: {zeros} with survival 0, {ones} with survial 1")

        data = []
        labels = []

        # Read subject path
        df = pd.read_csv(subjects_path)
                
        for i in range(df.shape[0]):
            
            subject = df.iloc[i,1]
            label = df.iloc[i,2]
            
            if label == 1.0:
                x_label = [0, 1]
            elif label == 0.0:
                x_label = [1, 0]
            else:
                raise Exception(f"Cannot establish what label is {label}")

            for image_path in glob.glob(f'{dataset_path}/0.0/{subject}/*.png'):
                im = imageio.imread(image_path)
                im = np.expand_dims(im, axis=2)
                data.append(im)
                labels.append(x_label)
                if x_label == 1.0:
                    raise Exception("Error bad classification")

            for image_path in glob.glob(f'{dataset_path}/1.0/{subject}/*.png'):
                im = imageio.imread(image_path)
                im = np.expand_dims(im, axis=2)
                data.append(im)
                labels.append(x_label)
                if x_label == 0.0:
                    raise Exception("Error bad classification")
            
        print(f"Max value is {np.max(data)}")

        self.data = np.asarray(data) / 255.0
        self.labels = np.asarray(labels)
    
        print(f"Data Shape: {self.data.shape}")
        
    def shuffle(self, seed=42):
        self.data, self.labels = shuffle(self.data, self.labels, random_state=seed)
        print(f"Shuffletd! Data Shape: {self.data.shape}")

    def train_and_test_split(self, test_size=0.2, seed=42):
        (self.trainX, self.testX, self.trainY, self.testY) = train_test_split(self.data, self.labels, test_size=test_size, stratify=self.labels, random_state=seed)
        print("trainX, trainY, testX, testY")
        print(self.trainX.shape, self.trainY.shape, self.testX.shape, self.testY.shape)

    def train_test_validation_split(self, validation_size=0.2, test_size=0.2, seed=42):
        (X, self.validationX, Y, self.validationY) = train_test_split(self.data, self.labels, test_size=validation_size, random_state=seed)
        (self.trainX, self.testX, self.trainY, self.testY) = train_test_split(X, Y, test_size=validation_size, random_state=seed)
        print("Train: ", (self.trainX.shape, self.trainY.shape))
        print("Test: ", (self.testX.shape, self.testY.shape))
        print("Validation: ", (self.validationX.shape, self.validationY.shape))

    def get_data_shape(self):
        return tuple(self.data.shape[1:])

# %%
    # sgd = SGD(lr=learning_rate)

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

from sklearn.model_selection import KFold

import matplotlib.pyplot as plt

class Trainer():
    
    def __init__(self, datasource, model_name, log_path="logs/scalars"):
        
        # Increasing this value might speed up fitting
        self.batch_size = 16
        
        # Save model
        self.datasource = datasource

        # Save log path
        self.log_path = log_path
        
        # Save model name
        self.model_name = model_name
        
    def train(self, batch_size=16, epochs=40):

        x_train, x_test = self.datasource.trainX, self.datasource.testX
        y_train, y_test = self.datasource.trainY, self.datasource.testY
            
        # Early stopping
        early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='accuracy', mode="max", patience=5)
        tensorboard_callback = keras.callbacks.TensorBoard(log_dir=f"{self.log_path}/{self.model_name}")

        # Get fresh model
        model = get_model(self.datasource.get_data_shape())
    
        # Fit
        fit = model.fit(
                x_train, y_train, 
                epochs=epochs,
                callbacks=[tensorboard_callback, early_stopping_callback],
                validation_data=(x_test, y_test), 
                # shuffle=True,
                batch_size=self.batch_size)

        # Save trained model
        model.save(f"{self.model_name}.h5")

        # Evaluate and print (test)
        self.save_results(model, x_test, y_test)

        # Save plot
        self.save_plot(fit, f"{self.model_name}.png")
        
    def train_test_validation(self, batch_size=16, epochs=40):

        x_train, x_test, x_validation = self.datasource.trainX, self.datasource.testX, self.datasource.validationX
        y_train, y_test, y_validation = self.datasource.trainY, self.datasource.testY, self.datasource.validationY
            
        # Early stopping
        early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='accuracy', mode="max", patience=5)
        tensorboard_callback = keras.callbacks.TensorBoard(log_dir=f"{self.log_path}/{self.model_name}")

        # Get fresh model
        model = get_model(self.datasource.get_data_shape())
    
        # Fit
        fit = model.fit(
                x_train, y_train, 
                epochs=epochs,
                callbacks=[tensorboard_callback, early_stopping_callback],
                validation_data=(x_test, y_test), 
                # shuffle=True,
                batch_size=self.batch_size)

        # Save trained model
        model.save(f"{self.model_name}.h5")

        # Evaluate and print (test)
        self.save_results(model, x_test, y_test)

        # Evaluate and print (validation)
        self.save_results(model, x_validation, y_validation)

        # Save plot
        self.save_plot(fit, f"{self.model_name}.png")
                
    # Train with k-fold (5)
    def train_with_kfold(self, batch_size=16, epochs=40, n_split=5):
                        
        fold = 0
        
        for train_index, test_index in KFold(n_split).split(self.datasource.data):
            
            fold = fold + 1
            
            x_train, x_test = self.datasource.data[train_index], self.datasource.data[test_index]
            y_train, y_test = self.datasource.labels[train_index], self.datasource.labels[test_index]
            
            print(f"Starting Kfold {fold}")

            # Early stopping
            early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='accuracy', mode="max", patience=5)
            tensorboard_callback = keras.callbacks.TensorBoard(log_dir="f{self.log_path}/{self.model_name}-{fold}")

            # Get fresh model
            model = get_model(self.datasource.get_data_shape())
    
            # Fit
            fit = model.fit(
                    x_train, y_train, 
                    epochs=epochs,
                    callbacks=[tensorboard_callback, early_stopping_callback],
                    validation_data=(x_test, y_test), 
                    # shuffle=True,
                    batch_size=self.batch_size)

            # Save trained model
            model.save(f"{self.model_name}-{fold}.h5")

            # Evaluate and print
            self.save_results(model, x_test, y_test)

            # Save plot
            self.save_plot(fit, f"{self.model_name}-{fold}.png")
        
    def save_results(self, model, test_x, test_y):
        # evaluate the model
        scores = model.evaluate(test_x, test_y, verbose=0)
        print("-------------------------")
        print("[", self.model_name, "]")
        for i in range(len(model.metrics_names)):
            print("%s: %.2f%%" % (model.metrics_names[i], scores[i]*100))
        print("-------------------------")
        
    def save_plot(self, fit, plot_path):

        fig = plt.figure(figsize=(40, 25))
        epoch = fit.epoch
        fontsize = 16

        plt.plot(fit.epoch, fit.history['accuracy'], marker="o", linewidth=2,
                 color="steelblue", label="accuracy")

        plt.plot(epoch, fit.history['loss'], marker="o", linewidth=2,
                 color="orange", label="loss")
        plt.plot(epoch, fit.history['val_accuracy'], marker="o", linewidth=2,
             color="red", label="test")
        plt.plot(epoch, fit.history['val_binary_crossentropy'], marker="o", linewidth=2,
             color="green", label="binary_crossentropy")
        plt.xlabel('epoch', fontsize=fontsize)
        plt.ylabel('% Accuracy', fontsize=fontsize)

        plt.xticks(fontsize=fontsize)
        plt.yticks(fontsize=fontsize)
        plt.legend(frameon=False, fontsize=30);

        plt.savefig(plot_path)

# %% [markdown]
# # One Shot

# %%
sequence = "rCBV"

percentile = 70

ds = Datasource(f"dataset-{sequence}-{percentile}", "datasets/dataset-mgmt.csv")

ds.shuffle()

ds.train_and_test_split()

# Trainer
trainer = Trainer(ds, f"dataset-{sequence}-{percentile}", f"model-mgmt-{sequence}-70")

trainer.train()
# Out:
# Loading 996 images: 398 with survival 0, 598 with survial 1
# Max value is 255
# Data Shape: (996, 192, 256, 1)
# Shuffletd! Data Shape: (996, 192, 256, 1)
# trainX, trainY, testX, testY
# (796, 192, 256, 1) (796, 2) (200, 192, 256, 1) (200, 2)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 796 samples, validate on 200 samples
# WARNING:tensorflow:From /.local/lib/python3.6/site-packages/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /.local/lib/python3.6/site-packages/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/40
# 796/796 [==============================] - 7s 9ms/step - loss: 1.3241 - accuracy: 0.4812 - binary_crossentropy: 1.3241 - val_loss: 0.6934 - val_accuracy: 0.5350 - val_binary_crossentropy: 0.6934
# WARNING:tensorflow:From /.local/lib/python3.6/site-packages/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/40
# 796/796 [==============================] - 1s 2ms/step - loss: 1.0835 - accuracy: 0.5653 - binary_crossentropy: 1.0835 - val_loss: 0.6839 - val_accuracy: 0.5950 - val_binary_crossentropy: 0.6839
# Epoch 3/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.9437 - accuracy: 0.6055 - binary_crossentropy: 0.9437 - val_loss: 0.6662 - val_accuracy: 0.6000 - val_binary_crossentropy: 0.6662
# Epoch 4/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.7624 - accuracy: 0.6583 - binary_crossentropy: 0.7624 - val_loss: 0.6582 - val_accuracy: 0.6150 - val_binary_crossentropy: 0.6582
# Epoch 5/40
# 796/796 [==============================] - 2s 2ms/step - loss: 0.6408 - accuracy: 0.7111 - binary_crossentropy: 0.6408 - val_loss: 0.6484 - val_accuracy: 0.6200 - val_binary_crossentropy: 0.6484
# Epoch 6/40
# 796/796 [==============================] - 2s 2ms/step - loss: 0.5753 - accuracy: 0.7211 - binary_crossentropy: 0.5753 - val_loss: 0.6312 - val_accuracy: 0.6250 - val_binary_crossentropy: 0.6312
# Epoch 7/40
# 796/796 [==============================] - 2s 2ms/step - loss: 0.5575 - accuracy: 0.7362 - binary_crossentropy: 0.5575 - val_loss: 0.5966 - val_accuracy: 0.6250 - val_binary_crossentropy: 0.5966
# Epoch 8/40
# 796/796 [==============================] - 2s 2ms/step - loss: 0.5052 - accuracy: 0.7688 - binary_crossentropy: 0.5052 - val_loss: 0.5533 - val_accuracy: 0.6450 - val_binary_crossentropy: 0.5533
# Epoch 9/40
# 796/796 [==============================] - 2s 2ms/step - loss: 0.4043 - accuracy: 0.8103 - binary_crossentropy: 0.4043 - val_loss: 0.5070 - val_accuracy: 0.6750 - val_binary_crossentropy: 0.5070
# Epoch 10/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.3878 - accuracy: 0.8178 - binary_crossentropy: 0.3878 - val_loss: 0.4507 - val_accuracy: 0.7100 - val_binary_crossentropy: 0.4507
# Epoch 11/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.3486 - accuracy: 0.8467 - binary_crossentropy: 0.3486 - val_loss: 0.3913 - val_accuracy: 0.7600 - val_binary_crossentropy: 0.3913
# Epoch 12/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.3311 - accuracy: 0.8518 - binary_crossentropy: 0.3311 - val_loss: 0.3227 - val_accuracy: 0.8350 - val_binary_crossentropy: 0.3227
# Epoch 13/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.3320 - accuracy: 0.8643 - binary_crossentropy: 0.3320 - val_loss: 0.2494 - val_accuracy: 0.9250 - val_binary_crossentropy: 0.2494
# Epoch 14/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.2894 - accuracy: 0.8719 - binary_crossentropy: 0.2894 - val_loss: 0.2211 - val_accuracy: 0.9400 - val_binary_crossentropy: 0.2211
# Epoch 15/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.2666 - accuracy: 0.8794 - binary_crossentropy: 0.2666 - val_loss: 0.1798 - val_accuracy: 0.9650 - val_binary_crossentropy: 0.1798
# Epoch 16/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.2419 - accuracy: 0.8882 - binary_crossentropy: 0.2419 - val_loss: 0.1590 - val_accuracy: 0.9700 - val_binary_crossentropy: 0.1590
# Epoch 17/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.2074 - accuracy: 0.9171 - binary_crossentropy: 0.2074 - val_loss: 0.1417 - val_accuracy: 0.9750 - val_binary_crossentropy: 0.1417
# Epoch 18/40
# 796/796 [==============================] - 2s 2ms/step - loss: 0.2216 - accuracy: 0.9070 - binary_crossentropy: 0.2216 - val_loss: 0.1320 - val_accuracy: 0.9750 - val_binary_crossentropy: 0.1320
# Epoch 19/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.1932 - accuracy: 0.9296 - binary_crossentropy: 0.1932 - val_loss: 0.1209 - val_accuracy: 0.9800 - val_binary_crossentropy: 0.1209
# Epoch 20/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.1939 - accuracy: 0.9183 - binary_crossentropy: 0.1939 - val_loss: 0.1084 - val_accuracy: 0.9850 - val_binary_crossentropy: 0.1084
# Epoch 21/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.1791 - accuracy: 0.9259 - binary_crossentropy: 0.1791 - val_loss: 0.1008 - val_accuracy: 0.9850 - val_binary_crossentropy: 0.1008
# Epoch 22/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.1593 - accuracy: 0.9322 - binary_crossentropy: 0.1593 - val_loss: 0.0932 - val_accuracy: 0.9850 - val_binary_crossentropy: 0.0932
# Epoch 23/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.1304 - accuracy: 0.9598 - binary_crossentropy: 0.1304 - val_loss: 0.0868 - val_accuracy: 0.9850 - val_binary_crossentropy: 0.0868
# Epoch 24/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.1408 - accuracy: 0.9573 - binary_crossentropy: 0.1408 - val_loss: 0.0815 - val_accuracy: 0.9850 - val_binary_crossentropy: 0.0815
# Epoch 25/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.1370 - accuracy: 0.9560 - binary_crossentropy: 0.1370 - val_loss: 0.0754 - val_accuracy: 0.9850 - val_binary_crossentropy: 0.0754
# Epoch 26/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.1283 - accuracy: 0.9422 - binary_crossentropy: 0.1283 - val_loss: 0.0715 - val_accuracy: 0.9900 - val_binary_crossentropy: 0.0715
# Epoch 27/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.0960 - accuracy: 0.9774 - binary_crossentropy: 0.0960 - val_loss: 0.0663 - val_accuracy: 0.9850 - val_binary_crossentropy: 0.0663
# Epoch 28/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.1025 - accuracy: 0.9648 - binary_crossentropy: 0.1025 - val_loss: 0.0633 - val_accuracy: 0.9850 - val_binary_crossentropy: 0.0633
# Epoch 29/40
# 796/796 [==============================] - 2s 2ms/step - loss: 0.0844 - accuracy: 0.9724 - binary_crossentropy: 0.0844 - val_loss: 0.0585 - val_accuracy: 0.9850 - val_binary_crossentropy: 0.0585
# Epoch 30/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.0900 - accuracy: 0.9661 - binary_crossentropy: 0.0900 - val_loss: 0.0558 - val_accuracy: 0.9900 - val_binary_crossentropy: 0.0558
# Epoch 31/40
# 796/796 [==============================] - 1s 2ms/step - loss: 0.0776 - accuracy: 0.9724 - binary_crossentropy: 0.0776 - val_loss: 0.0516 - val_accuracy: 0.9900 - val_binary_crossentropy: 0.0516
# Epoch 32/40
# 796/796 [==============================] - 2s 2ms/step - loss: 0.0839 - accuracy: 0.9774 - binary_crossentropy: 0.0839 - val_loss: 0.0484 - val_accuracy: 0.9850 - val_binary_crossentropy: 0.0484
# -------------------------
# [ dataset-rCBV-70 ]
# loss: 4.84%
# accuracy: 98.50%
# binary_crossentropy: 4.84%
# -------------------------

# %% [markdown]
# # Not Tumor Analysis

# %%
import tensorflow.keras as keras

model = keras.models.load_model("../mastrogiovanni/models/dataset-FLAIR-70-5.h5")

print("Loaded model from disk")

ds = Datasource(f"dataset-{sequence}-not-tumor", "datasets/dataset-survivor.csv")

# evaluate the model
scores = model.evaluate(ds.data, ds.labels, verbose=0)
for i in range(len(model.metrics_names)):
    print("%s: %.2f%%" % (model.metrics_names[i], scores[i]*100))
# Out:
# Loaded model from disk
# Loading 10451 images: 4545 with survival 0, 5906 with survial 1
# Max value is 255
# Data Shape: (10451, 192, 256, 1)
# loss: 124.49%
# acc: 54.69%
# binary_crossentropy: 124.49%

# %%
        # evaluate the model
        scores = model.evaluate(test_x, test_y, verbose=0)
        print("-------------------------")
        print("[", self.model_name, "]")
        for i in range(len(model.metrics_names)):
            print("%s: %.2f%%" % (model.metrics_names[i], scores[i]*100))
        print("-------------------------")

# %%
sequence = "FLAIR"

ds = Datasource(f"dataset-{sequence}-not-tumor", "datasets/dataset-survivor.csv")

ds.shuffle()

ds.train_and_test_split()

# Trainer
trainer = Trainer(ds, f"dataset-{sequence}-{percentile}", f"model-mgmt-{sequence}-70")

trainer.train()
# Out:
# Loading 10451 images: 4545 with survival 0, 5906 with survial 1
# Max value is 255
# Data Shape: (10451, 192, 256, 1)
# Shuffletd! Data Shape: (10451, 192, 256, 1)
# trainX, trainY, testX, testY
# (8360, 192, 256, 1) (8360, 2) (2091, 192, 256, 1) (2091, 2)
# Train on 8360 samples, validate on 2091 samples
# Epoch 1/40
# 8360/8360 [==============================] - 16s 2ms/step - loss: 1.0139 - accuracy: 0.5341 - binary_crossentropy: 1.0139 - val_loss: 0.6539 - val_accuracy: 0.5983 - val_binary_crossentropy: 0.6539
# Epoch 2/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.7384 - accuracy: 0.5829 - binary_crossentropy: 0.7384 - val_loss: 0.5913 - val_accuracy: 0.6772 - val_binary_crossentropy: 0.5913
# Epoch 3/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.6471 - accuracy: 0.6339 - binary_crossentropy: 0.6471 - val_loss: 0.5541 - val_accuracy: 0.7116 - val_binary_crossentropy: 0.5541
# Epoch 4/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.5997 - accuracy: 0.6599 - binary_crossentropy: 0.5997 - val_loss: 0.5270 - val_accuracy: 0.7418 - val_binary_crossentropy: 0.5270
# Epoch 5/40
# 8360/8360 [==============================] - 15s 2ms/step - loss: 0.5588 - accuracy: 0.6953 - binary_crossentropy: 0.5588 - val_loss: 0.4835 - val_accuracy: 0.7771 - val_binary_crossentropy: 0.4835
# Epoch 6/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.5150 - accuracy: 0.7307 - binary_crossentropy: 0.5150 - val_loss: 0.4447 - val_accuracy: 0.7996 - val_binary_crossentropy: 0.4447
# Epoch 7/40
# 8360/8360 [==============================] - 16s 2ms/step - loss: 0.4774 - accuracy: 0.7591 - binary_crossentropy: 0.4774 - val_loss: 0.4047 - val_accuracy: 0.8192 - val_binary_crossentropy: 0.4047
# Epoch 8/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.4343 - accuracy: 0.7789 - binary_crossentropy: 0.4343 - val_loss: 0.3795 - val_accuracy: 0.8374 - val_binary_crossentropy: 0.3795
# Epoch 9/40
# 8360/8360 [==============================] - 15s 2ms/step - loss: 0.4000 - accuracy: 0.8043 - binary_crossentropy: 0.4000 - val_loss: 0.3387 - val_accuracy: 0.8546 - val_binary_crossentropy: 0.3387
# Epoch 10/40
# 8360/8360 [==============================] - 16s 2ms/step - loss: 0.3599 - accuracy: 0.8261 - binary_crossentropy: 0.3599 - val_loss: 0.3132 - val_accuracy: 0.8733 - val_binary_crossentropy: 0.3132
# Epoch 11/40
# 8360/8360 [==============================] - 15s 2ms/step - loss: 0.3300 - accuracy: 0.8443 - binary_crossentropy: 0.3300 - val_loss: 0.2832 - val_accuracy: 0.8828 - val_binary_crossentropy: 0.2832
# Epoch 12/40
# 8360/8360 [==============================] - 15s 2ms/step - loss: 0.3000 - accuracy: 0.8593 - binary_crossentropy: 0.3000 - val_loss: 0.2648 - val_accuracy: 0.8847 - val_binary_crossentropy: 0.2648
# Epoch 13/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.2750 - accuracy: 0.8744 - binary_crossentropy: 0.2750 - val_loss: 0.2433 - val_accuracy: 0.8943 - val_binary_crossentropy: 0.2433
# Epoch 14/40
# 8360/8360 [==============================] - 13s 2ms/step - loss: 0.2531 - accuracy: 0.8821 - binary_crossentropy: 0.2531 - val_loss: 0.2272 - val_accuracy: 0.9000 - val_binary_crossentropy: 0.2272
# Epoch 15/40
# 8360/8360 [==============================] - 15s 2ms/step - loss: 0.2357 - accuracy: 0.8890 - binary_crossentropy: 0.2357 - val_loss: 0.2121 - val_accuracy: 0.9067 - val_binary_crossentropy: 0.2121
# Epoch 16/40
# 8360/8360 [==============================] - 15s 2ms/step - loss: 0.2187 - accuracy: 0.8989 - binary_crossentropy: 0.2187 - val_loss: 0.2036 - val_accuracy: 0.9072 - val_binary_crossentropy: 0.2036
# Epoch 17/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.2003 - accuracy: 0.9066 - binary_crossentropy: 0.2003 - val_loss: 0.1929 - val_accuracy: 0.9130 - val_binary_crossentropy: 0.1929
# Epoch 18/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.1871 - accuracy: 0.9110 - binary_crossentropy: 0.1871 - val_loss: 0.1754 - val_accuracy: 0.9187 - val_binary_crossentropy: 0.1754
# Epoch 19/40
# 8360/8360 [==============================] - 15s 2ms/step - loss: 0.1759 - accuracy: 0.9167 - binary_crossentropy: 0.1759 - val_loss: 0.1659 - val_accuracy: 0.9244 - val_binary_crossentropy: 0.1659
# Epoch 20/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.1615 - accuracy: 0.9256 - binary_crossentropy: 0.1615 - val_loss: 0.1583 - val_accuracy: 0.9302 - val_binary_crossentropy: 0.1583
# Epoch 21/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.1514 - accuracy: 0.9278 - binary_crossentropy: 0.1514 - val_loss: 0.1473 - val_accuracy: 0.9302 - val_binary_crossentropy: 0.1473
# Epoch 22/40
# 8360/8360 [==============================] - 15s 2ms/step - loss: 0.1476 - accuracy: 0.9313 - binary_crossentropy: 0.1476 - val_loss: 0.1481 - val_accuracy: 0.9254 - val_binary_crossentropy: 0.1481
# Epoch 23/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.1413 - accuracy: 0.9334 - binary_crossentropy: 0.1413 - val_loss: 0.1400 - val_accuracy: 0.9330 - val_binary_crossentropy: 0.1400
# Epoch 24/40
# 8360/8360 [==============================] - 15s 2ms/step - loss: 0.1314 - accuracy: 0.9410 - binary_crossentropy: 0.1314 - val_loss: 0.1327 - val_accuracy: 0.9359 - val_binary_crossentropy: 0.1327
# Epoch 25/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.1258 - accuracy: 0.9382 - binary_crossentropy: 0.1258 - val_loss: 0.1275 - val_accuracy: 0.9311 - val_binary_crossentropy: 0.1275
# Epoch 26/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.1227 - accuracy: 0.9391 - binary_crossentropy: 0.1227 - val_loss: 0.1243 - val_accuracy: 0.9374 - val_binary_crossentropy: 0.1243
# Epoch 27/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.1143 - accuracy: 0.9434 - binary_crossentropy: 0.1143 - val_loss: 0.1226 - val_accuracy: 0.9397 - val_binary_crossentropy: 0.1226
# Epoch 28/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.1115 - accuracy: 0.9455 - binary_crossentropy: 0.1115 - val_loss: 0.1231 - val_accuracy: 0.9378 - val_binary_crossentropy: 0.1231
# Epoch 29/40
# 8360/8360 [==============================] - 15s 2ms/step - loss: 0.1061 - accuracy: 0.9470 - binary_crossentropy: 0.1061 - val_loss: 0.1149 - val_accuracy: 0.9417 - val_binary_crossentropy: 0.1149
# Epoch 30/40
# 8360/8360 [==============================] - 15s 2ms/step - loss: 0.1090 - accuracy: 0.9461 - binary_crossentropy: 0.1090 - val_loss: 0.1149 - val_accuracy: 0.9345 - val_binary_crossentropy: 0.1149
# Epoch 31/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.1013 - accuracy: 0.9492 - binary_crossentropy: 0.1013 - val_loss: 0.1200 - val_accuracy: 0.9378 - val_binary_crossentropy: 0.1200
# Epoch 32/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.0982 - accuracy: 0.9536 - binary_crossentropy: 0.0982 - val_loss: 0.1096 - val_accuracy: 0.9388 - val_binary_crossentropy: 0.1096
# Epoch 33/40
# 8360/8360 [==============================] - 15s 2ms/step - loss: 0.0973 - accuracy: 0.9512 - binary_crossentropy: 0.0973 - val_loss: 0.1099 - val_accuracy: 0.9421 - val_binary_crossentropy: 0.1099
# Epoch 34/40
# 8360/8360 [==============================] - 15s 2ms/step - loss: 0.0938 - accuracy: 0.9544 - binary_crossentropy: 0.0938 - val_loss: 0.1087 - val_accuracy: 0.9359 - val_binary_crossentropy: 0.1087
# Epoch 35/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.0941 - accuracy: 0.9523 - binary_crossentropy: 0.0941 - val_loss: 0.1038 - val_accuracy: 0.9383 - val_binary_crossentropy: 0.1038
# Epoch 36/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.0901 - accuracy: 0.9535 - binary_crossentropy: 0.0901 - val_loss: 0.1020 - val_accuracy: 0.9464 - val_binary_crossentropy: 0.1020
# Epoch 37/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.0867 - accuracy: 0.9583 - binary_crossentropy: 0.0867 - val_loss: 0.1045 - val_accuracy: 0.9455 - val_binary_crossentropy: 0.1045
# Epoch 38/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.0856 - accuracy: 0.9589 - binary_crossentropy: 0.0856 - val_loss: 0.0987 - val_accuracy: 0.9517 - val_binary_crossentropy: 0.0987
# Epoch 39/40
# 8360/8360 [==============================] - 15s 2ms/step - loss: 0.0856 - accuracy: 0.9554 - binary_crossentropy: 0.0856 - val_loss: 0.0993 - val_accuracy: 0.9455 - val_binary_crossentropy: 0.0993
# Epoch 40/40
# 8360/8360 [==============================] - 14s 2ms/step - loss: 0.0825 - accuracy: 0.9600 - binary_crossentropy: 0.0825 - val_loss: 0.0991 - val_accuracy: 0.9493 - val_binary_crossentropy: 0.0991
# -------------------------
# [ dataset-FLAIR-70 ]
# loss: 9.91%
# accuracy: 94.93%
# binary_crossentropy: 9.91%
# -------------------------

# %% [markdown]
# # Complete Train Set

# %%
# %%time

for sequence in ["T1", "ADC", "FLAIR"]:
    
    for percentile in [70, 50, 30]:
        
        if sequence == "T1" and percentile == 70:
            next
        
        # Read datasource
        ds = Datasource(f"dataset-{sequence}-{percentile}")

        ds.shuffle()

        ds.train_and_test_split()

        # Get model based on data shape
        model = get_model(ds.get_data_shape())

        # Trainer
        trainer = Trainer(ds, f"dataset-{sequence}-{percentile}")

        # Training
        trainer.train_with_kfold()

# %%
# Final Validation

# %%
# %%time

sequence = "FLAIR"
    
percentile = 70
        
# Read datasource
ds = Datasource(f"dataset-{sequence}-{percentile}", "dataset-survivor.csv")

# shuffle
ds.shuffle()

# Train, test and validation
ds.train_test_validation_split()

# Trainer
trainer = Trainer(ds, f"dataset-{sequence}-{percentile}")

# Training
trainer.train()

# %%
from numba import cuda
cuda.select_device(0)
cuda.close()

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir logs/scalars

# %%
# evaluate the model
scores = model.evaluate(testX, testY, verbose=0)
for i in range(len(model.metrics_names)):
    print("%s: %.2f%%" % (model.metrics_names[i], scores[i]*100))

# %%
result = model.predict(testX)

# %%
for i in range(result.shape[0]):
    print(f"Answer: {testY[i]} => Prediction: {result[i].round(decimals=2)}")

# %%
import tensorflow.keras as keras

new_model = keras.models.load_model('perc_70.h5')

# evaluate the model
scores = model.evaluate(testX, testY, verbose=0)
for i in range(len(model.metrics_names)):
    print("%s: %.2f%%" % (model.metrics_names[i], scores[i]*100))
